# %%
import csv
import gzip
import os
import scipy.io
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
matrix_dir = "H:\\SingleCell\\smc009\\filtered_feature_bc_matrix\\"

# %%
mat = scipy.io.mmread(os.path.join(matrix_dir, "matrix.mtx.gz"))

# %%
features_path = os.path.join(matrix_dir, "features.tsv.gz")
feature_ids = [row[0] for row in csv.reader(gzip.open(features_path, mode = 'rt'), delimiter="\t")]
gene_names = [row[1] for row in csv.reader(gzip.open(features_path, mode = 'rt'), delimiter="\t")]
feature_types = [row[2] for row in csv.reader(gzip.open(features_path, mode = 'rt'), delimiter="\t")]

# %%
barcodes_path = os.path.join(matrix_dir, "barcodes.tsv.gz")
barcodes = [row[0] for row in csv.reader(gzip.open(barcodes_path, mode = 'rt'), delimiter="\t")]

# %%
type(mat)
mat
# Out:
# <33538x20498 sparse matrix of type '<class 'numpy.int64'>'
# 	with 38751361 stored elements in COOrdinate format>

# %% [markdown]
# scipy sparse matrix to pandas dataframe

# %%
mat1 = pd.DataFrame.sparse.from_spmatrix(mat)

# %%
mat1.columns = barcodes
mat1.index = gene_names

# %%
mat1.head()
# Out:
#              AAACCCAAGAACCCGA-1  AAACCCAAGAAGCCTG-1  AAACCCAAGACAGCGT-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCAAGACCTCCG-1  AAACCCAAGAGCAACC-1  AAACCCAAGAGCAGAA-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCAAGTTTGTCG-1  AAACCCACACACCTAA-1  AAACCCACACACGCCA-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCACACCAGTAT-1  ...  TTTGTTGGTCTGCAAT-1  TTTGTTGGTGACAGCA-1  \
# MIR1302-2HG                   0  ...                   0                   0
# FAM138A                       0  ...                   0                   0
# OR4F5                         0  ...                   0                   0
# AL627309.1                    0  ...                   0                   0
# AL627309.3                    0  ...                   0                   0
#
#              TTTGTTGGTGGTCTTA-1  TTTGTTGGTGTGGACA-1  TTTGTTGGTTTCACAG-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGTCAACTCTT-1  TTTGTTGTCCGCAACG-1  TTTGTTGTCGGCTGGT-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGTCTCCAATT-1  TTTGTTGTCTTGAGCA-1
# MIR1302-2HG                   0                   0
# FAM138A                       0                   0
# OR4F5                         0                   0
# AL627309.1                    0                   0
# AL627309.3                    0                   0
#
# [5 rows x 20498 columns]

# %%
mat1.to_csv("H:\\SingleCell\\smc009\\smc009matrix_featurebarcode.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-f1490ea39d7d> in <module>
# ----> 1 mat1.to_csv("H:\\SingleCell\\smc009\\smc009matrix_featurebarcode.csv")
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Miniconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ~\Miniconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     321                 break
#     322
# --> 323             self._save_chunk(start_i, end_i)
#     324
#     325     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~\Miniconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     336                 decimal=self.decimal,
#     337                 date_format=self.date_format,
# --> 338                 quoting=self.quoting,
#     339             )
#     340
#
# ~\Miniconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#    1815         values = self.values
#    1816         if slicer is not None:
# -> 1817             values = values[slicer]
#    1818         mask = isna(values)
#    1819
#
# ~\Miniconda3\lib\site-packages\pandas\core\arrays\sparse\array.py in __getitem__(self, key)
#     757             # TODO: this logic is surely elsewhere
#     758             # TODO: this could be more efficient
# --> 759             indices = np.arange(len(self), dtype=np.int32)[key]
#     760             return self.take(indices)
#     761         else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### kmeans clustering

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
kmeans = KMeans(n_clusters = 30, random_state=0).fit(mat1)

# %%
kmeans.labels_.max()
# Out:
# 29

# %%
mat1['cluster_id'] = kmeans.labels_

# %%
mat1
# Out:
#              AAACCCAAGAACCCGA-1  AAACCCAAGAAGCCTG-1  AAACCCAAGACAGCGT-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   1                   0
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              AAACCCAAGACCTCCG-1  AAACCCAAGAGCAACC-1  AAACCCAAGAGCAGAA-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   0                   1
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              AAACCCAAGTTTGTCG-1  AAACCCACACACCTAA-1  AAACCCACACACGCCA-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   0                   0
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              AAACCCACACCAGTAT-1  ...  TTTGTTGGTGACAGCA-1  TTTGTTGGTGGTCTTA-1  \
# MIR1302-2HG                   0  ...                   0                   0
# FAM138A                       0  ...                   0                   0
# OR4F5                         0  ...                   0                   0
# AL627309.1                    0  ...                   0                   0
# AL627309.3                    0  ...                   0                   0
# ...                         ...  ...                 ...                 ...
# AC233755.2                    0  ...                   0                   0
# AC233755.1                    0  ...                   0                   0
# AC240274.1                    0  ...                   0                   0
# AC213203.1                    0  ...                   0                   0
# FAM231C                       0  ...                   0                   0
#
#              TTTGTTGGTGTGGACA-1  TTTGTTGGTTTCACAG-1  TTTGTTGTCAACTCTT-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   0                   0
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              TTTGTTGTCCGCAACG-1  TTTGTTGTCGGCTGGT-1  TTTGTTGTCTCCAATT-1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   0                   0
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              TTTGTTGTCTTGAGCA-1  cluster_id
# MIR1302-2HG                   0           3
# FAM138A                       0           3
# OR4F5                         0           3
# AL627309.1                    0           3
# AL627309.3                    0           3
# ...                         ...         ...
# AC233755.2                    0           3
# AC233755.1                    0           3
# AC240274.1                    0           3
# AC213203.1                    0           3
# FAM231C                       0           3
#
# [33538 rows x 20499 columns]

# %%
mat1_transpose = mat1.transpose()

# %%
mat1_transpose.loc[["cluster_id"]]
# Out:
#            MIR1302-2HG FAM138A OR4F5 AL627309.1 AL627309.3 AL627309.2  \
# cluster_id           3       3     3          3          3          3
#
#            AL627309.4 AL732372.1 OR4F29 AC114498.1  ... AC007325.2 BX072566.1  \
# cluster_id          3          3      3          3  ...          3          3
#
#            AL354822.1 AC023491.2 AC004556.1 AC233755.2 AC233755.1 AC240274.1  \
# cluster_id          3          3          3          3          3          3
#
#            AC213203.1 FAM231C
# cluster_id          3       3
#
# [1 rows x 33538 columns]

# %%
mat1_t_del = mat1_transpose.drop('cluster_id', axis=0)

# %%
mat1_t_del
# Out:
#                    MIR1302-2HG FAM138A OR4F5 AL627309.1 AL627309.3 AL627309.2  \
# AAACCCAAGAACCCGA-1           0       0     0          0          0          0
# AAACCCAAGAAGCCTG-1           0       0     0          0          0          0
# AAACCCAAGACAGCGT-1           0       0     0          0          0          0
# AAACCCAAGACCTCCG-1           0       0     0          0          0          0
# AAACCCAAGAGCAACC-1           0       0     0          0          0          0
# ...                        ...     ...   ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1           0       0     0          0          0          0
# TTTGTTGTCCGCAACG-1           0       0     0          0          0          0
# TTTGTTGTCGGCTGGT-1           0       0     0          0          0          0
# TTTGTTGTCTCCAATT-1           0       0     0          0          0          0
# TTTGTTGTCTTGAGCA-1           0       0     0          0          0          0
#
#                    AL627309.4 AL732372.1 OR4F29 AC114498.1  ... AC007325.2  \
# AAACCCAAGAACCCGA-1          0          0      0          0  ...          0
# AAACCCAAGAAGCCTG-1          0          0      0          0  ...          0
# AAACCCAAGACAGCGT-1          0          0      0          0  ...          0
# AAACCCAAGACCTCCG-1          0          0      0          0  ...          0
# AAACCCAAGAGCAACC-1          0          0      0          0  ...          0
# ...                       ...        ...    ...        ...  ...        ...
# TTTGTTGTCAACTCTT-1          0          0      0          0  ...          0
# TTTGTTGTCCGCAACG-1          0          0      0          0  ...          0
# TTTGTTGTCGGCTGGT-1          0          0      0          0  ...          0
# TTTGTTGTCTCCAATT-1          0          0      0          0  ...          0
# TTTGTTGTCTTGAGCA-1          0          0      0          0  ...          0
#
#                    BX072566.1 AL354822.1 AC023491.2 AC004556.1 AC233755.2  \
# AAACCCAAGAACCCGA-1          0          0          0          0          0
# AAACCCAAGAAGCCTG-1          0          0          0          0          0
# AAACCCAAGACAGCGT-1          0          0          0          0          0
# AAACCCAAGACCTCCG-1          0          0          0          0          0
# AAACCCAAGAGCAACC-1          0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1          0          0          0          0          0
# TTTGTTGTCCGCAACG-1          0          0          0          0          0
# TTTGTTGTCGGCTGGT-1          0          0          0          0          0
# TTTGTTGTCTCCAATT-1          0          0          0          0          0
# TTTGTTGTCTTGAGCA-1          0          0          0          0          0
#
#                    AC233755.1 AC240274.1 AC213203.1 FAM231C
# AAACCCAAGAACCCGA-1          0          0          0       0
# AAACCCAAGAAGCCTG-1          0          1          0       0
# AAACCCAAGACAGCGT-1          0          0          0       0
# AAACCCAAGACCTCCG-1          0          0          0       0
# AAACCCAAGAGCAACC-1          0          0          0       0
# ...                       ...        ...        ...     ...
# TTTGTTGTCAACTCTT-1          0          0          0       0
# TTTGTTGTCCGCAACG-1          0          0          0       0
# TTTGTTGTCGGCTGGT-1          0          0          0       0
# TTTGTTGTCTCCAATT-1          0          0          0       0
# TTTGTTGTCTTGAGCA-1          0          0          0       0
#
# [20498 rows x 33538 columns]

# %%
kmeans1 = KMeans(n_clusters = 30, random_state=0).fit(mat1_t_del)

# %%
mat1_t_del['cluster_id'] = kmeans1.labels_

# %%
mat1_t_del
# Out:
#                    MIR1302-2HG FAM138A OR4F5 AL627309.1 AL627309.3 AL627309.2  \
# AAACCCAAGAACCCGA-1           0       0     0          0          0          0
# AAACCCAAGAAGCCTG-1           0       0     0          0          0          0
# AAACCCAAGACAGCGT-1           0       0     0          0          0          0
# AAACCCAAGACCTCCG-1           0       0     0          0          0          0
# AAACCCAAGAGCAACC-1           0       0     0          0          0          0
# ...                        ...     ...   ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1           0       0     0          0          0          0
# TTTGTTGTCCGCAACG-1           0       0     0          0          0          0
# TTTGTTGTCGGCTGGT-1           0       0     0          0          0          0
# TTTGTTGTCTCCAATT-1           0       0     0          0          0          0
# TTTGTTGTCTTGAGCA-1           0       0     0          0          0          0
#
#                    AL627309.4 AL732372.1 OR4F29 AC114498.1  ... BX072566.1  \
# AAACCCAAGAACCCGA-1          0          0      0          0  ...          0
# AAACCCAAGAAGCCTG-1          0          0      0          0  ...          0
# AAACCCAAGACAGCGT-1          0          0      0          0  ...          0
# AAACCCAAGACCTCCG-1          0          0      0          0  ...          0
# AAACCCAAGAGCAACC-1          0          0      0          0  ...          0
# ...                       ...        ...    ...        ...  ...        ...
# TTTGTTGTCAACTCTT-1          0          0      0          0  ...          0
# TTTGTTGTCCGCAACG-1          0          0      0          0  ...          0
# TTTGTTGTCGGCTGGT-1          0          0      0          0  ...          0
# TTTGTTGTCTCCAATT-1          0          0      0          0  ...          0
# TTTGTTGTCTTGAGCA-1          0          0      0          0  ...          0
#
#                    AL354822.1 AC023491.2 AC004556.1 AC233755.2 AC233755.1  \
# AAACCCAAGAACCCGA-1          0          0          0          0          0
# AAACCCAAGAAGCCTG-1          0          0          0          0          0
# AAACCCAAGACAGCGT-1          0          0          0          0          0
# AAACCCAAGACCTCCG-1          0          0          0          0          0
# AAACCCAAGAGCAACC-1          0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1          0          0          0          0          0
# TTTGTTGTCCGCAACG-1          0          0          0          0          0
# TTTGTTGTCGGCTGGT-1          0          0          0          0          0
# TTTGTTGTCTCCAATT-1          0          0          0          0          0
# TTTGTTGTCTTGAGCA-1          0          0          0          0          0
#
#                    AC240274.1 AC213203.1 FAM231C cluster_id
# AAACCCAAGAACCCGA-1          0          0       0          1
# AAACCCAAGAAGCCTG-1          1          0       0         13
# AAACCCAAGACAGCGT-1          0          0       0          5
# AAACCCAAGACCTCCG-1          0          0       0          1
# AAACCCAAGAGCAACC-1          0          0       0          7
# ...                       ...        ...     ...        ...
# TTTGTTGTCAACTCTT-1          0          0       0          1
# TTTGTTGTCCGCAACG-1          0          0       0         18
# TTTGTTGTCGGCTGGT-1          0          0       0          1
# TTTGTTGTCTCCAATT-1          0          0       0          7
# TTTGTTGTCTTGAGCA-1          0          0       0          1
#
# [20498 rows x 33539 columns]

# %%
mat1_t_del[mat1_t_del['cluster_id'] == 1]
# Out:
#                    MIR1302-2HG FAM138A OR4F5 AL627309.1 AL627309.3 AL627309.2  \
# AAACCCAAGAACCCGA-1           0       0     0          0          0          0
# AAACCCAAGACCTCCG-1           0       0     0          0          0          0
# AAACCCACACACCTAA-1           0       0     0          0          0          0
# AAACCCACACACGCCA-1           0       0     0          0          0          0
# AAACCCACACCAGTAT-1           0       0     0          0          0          0
# ...                        ...     ...   ...        ...        ...        ...
# TTTGTTGGTGACAGCA-1           0       0     0          0          0          0
# TTTGTTGGTTTCACAG-1           0       0     0          0          0          0
# TTTGTTGTCAACTCTT-1           0       0     0          0          0          0
# TTTGTTGTCGGCTGGT-1           0       0     0          0          0          0
# TTTGTTGTCTTGAGCA-1           0       0     0          0          0          0
#
#                    AL627309.4 AL732372.1 OR4F29 AC114498.1  ... BX072566.1  \
# AAACCCAAGAACCCGA-1          0          0      0          0  ...          0
# AAACCCAAGACCTCCG-1          0          0      0          0  ...          0
# AAACCCACACACCTAA-1          0          0      0          0  ...          0
# AAACCCACACACGCCA-1          0          0      0          0  ...          0
# AAACCCACACCAGTAT-1          0          0      0          0  ...          0
# ...                       ...        ...    ...        ...  ...        ...
# TTTGTTGGTGACAGCA-1          0          0      0          0  ...          0
# TTTGTTGGTTTCACAG-1          0          0      0          0  ...          0
# TTTGTTGTCAACTCTT-1          0          0      0          0  ...          0
# TTTGTTGTCGGCTGGT-1          0          0      0          0  ...          0
# TTTGTTGTCTTGAGCA-1          0          0      0          0  ...          0
#
#                    AL354822.1 AC023491.2 AC004556.1 AC233755.2 AC233755.1  \
# AAACCCAAGAACCCGA-1          0          0          0          0          0
# AAACCCAAGACCTCCG-1          0          0          0          0          0
# AAACCCACACACCTAA-1          0          0          0          0          0
# AAACCCACACACGCCA-1          0          0          0          0          0
# AAACCCACACCAGTAT-1          0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# TTTGTTGGTGACAGCA-1          0          0          0          0          0
# TTTGTTGGTTTCACAG-1          0          0          0          0          0
# TTTGTTGTCAACTCTT-1          0          0          0          0          0
# TTTGTTGTCGGCTGGT-1          0          0          0          0          0
# TTTGTTGTCTTGAGCA-1          0          0          0          0          0
#
#                    AC240274.1 AC213203.1 FAM231C cluster_id
# AAACCCAAGAACCCGA-1          0          0       0          1
# AAACCCAAGACCTCCG-1          0          0       0          1
# AAACCCACACACCTAA-1          0          0       0          1
# AAACCCACACACGCCA-1          0          0       0          1
# AAACCCACACCAGTAT-1          0          0       0          1
# ...                       ...        ...     ...        ...
# TTTGTTGGTGACAGCA-1          0          0       0          1
# TTTGTTGGTTTCACAG-1          0          0       0          1
# TTTGTTGTCAACTCTT-1          0          0       0          1
# TTTGTTGTCGGCTGGT-1          0          0       0          1
# TTTGTTGTCTTGAGCA-1          0          0       0          1
#
# [10105 rows x 33539 columns]

# %%
mat1_t_del.loc[:, mat1_t_del.columns != 'cluster_id']
# Out:
#                    MIR1302-2HG FAM138A OR4F5 AL627309.1 AL627309.3 AL627309.2  \
# AAACCCAAGAACCCGA-1           0       0     0          0          0          0
# AAACCCAAGAAGCCTG-1           0       0     0          0          0          0
# AAACCCAAGACAGCGT-1           0       0     0          0          0          0
# AAACCCAAGACCTCCG-1           0       0     0          0          0          0
# AAACCCAAGAGCAACC-1           0       0     0          0          0          0
# ...                        ...     ...   ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1           0       0     0          0          0          0
# TTTGTTGTCCGCAACG-1           0       0     0          0          0          0
# TTTGTTGTCGGCTGGT-1           0       0     0          0          0          0
# TTTGTTGTCTCCAATT-1           0       0     0          0          0          0
# TTTGTTGTCTTGAGCA-1           0       0     0          0          0          0
#
#                    AL627309.4 AL732372.1 OR4F29 AC114498.1  ... AC007325.2  \
# AAACCCAAGAACCCGA-1          0          0      0          0  ...          0
# AAACCCAAGAAGCCTG-1          0          0      0          0  ...          0
# AAACCCAAGACAGCGT-1          0          0      0          0  ...          0
# AAACCCAAGACCTCCG-1          0          0      0          0  ...          0
# AAACCCAAGAGCAACC-1          0          0      0          0  ...          0
# ...                       ...        ...    ...        ...  ...        ...
# TTTGTTGTCAACTCTT-1          0          0      0          0  ...          0
# TTTGTTGTCCGCAACG-1          0          0      0          0  ...          0
# TTTGTTGTCGGCTGGT-1          0          0      0          0  ...          0
# TTTGTTGTCTCCAATT-1          0          0      0          0  ...          0
# TTTGTTGTCTTGAGCA-1          0          0      0          0  ...          0
#
#                    BX072566.1 AL354822.1 AC023491.2 AC004556.1 AC233755.2  \
# AAACCCAAGAACCCGA-1          0          0          0          0          0
# AAACCCAAGAAGCCTG-1          0          0          0          0          0
# AAACCCAAGACAGCGT-1          0          0          0          0          0
# AAACCCAAGACCTCCG-1          0          0          0          0          0
# AAACCCAAGAGCAACC-1          0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# TTTGTTGTCAACTCTT-1          0          0          0          0          0
# TTTGTTGTCCGCAACG-1          0          0          0          0          0
# TTTGTTGTCGGCTGGT-1          0          0          0          0          0
# TTTGTTGTCTCCAATT-1          0          0          0          0          0
# TTTGTTGTCTTGAGCA-1          0          0          0          0          0
#
#                    AC233755.1 AC240274.1 AC213203.1 FAM231C
# AAACCCAAGAACCCGA-1          0          0          0       0
# AAACCCAAGAAGCCTG-1          0          1          0       0
# AAACCCAAGACAGCGT-1          0          0          0       0
# AAACCCAAGACCTCCG-1          0          0          0       0
# AAACCCAAGAGCAACC-1          0          0          0       0
# ...                       ...        ...        ...     ...
# TTTGTTGTCAACTCTT-1          0          0          0       0
# TTTGTTGTCCGCAACG-1          0          0          0       0
# TTTGTTGTCGGCTGGT-1          0          0          0       0
# TTTGTTGTCTCCAATT-1          0          0          0       0
# TTTGTTGTCTTGAGCA-1          0          0          0       0
#
# [20498 rows x 33538 columns]

# %%
mat1_t_del[mat1_t_del['cluster_id'] == 1].loc[:, mat1_t_del.columns != 'cluster_id'].sum(axis=1)
# Out:
# AAACCCAAGAACCCGA-1     844.0
# AAACCCAAGACCTCCG-1     599.0
# AAACCCACACACCTAA-1     568.0
# AAACCCACACACGCCA-1     550.0
# AAACCCACACCAGTAT-1     636.0
#                        ...
# TTTGTTGGTGACAGCA-1    2282.0
# TTTGTTGGTTTCACAG-1     722.0
# TTTGTTGTCAACTCTT-1     858.0
# TTTGTTGTCGGCTGGT-1     562.0
# TTTGTTGTCTTGAGCA-1    1289.0
# Length: 10105, dtype: float64

# %%
cl1sum = mat1_t_del[mat1_t_del['cluster_id'] == 1].loc[:, mat1_t_del.columns != 'cluster_id'].sum(axis=0)

# %%
mat1_t_del['cluster_id'].unique()
# Out:
# array([ 1, 13,  5,  7, 11, 14, 18, 15, 20, 12, 27, 22, 26, 21,  6,  0, 17,
#         4, 24, 19, 25,  9,  2,  3, 28,  8, 10, 16, 29, 23])

# %%
len(mat1_t_del['cluster_id'].unique())
# Out:
# 30

# %%
cl1sum.sort_values(ascending = False).head(50)
# Out:
# MT-CO2     291661.0
# MT-CO3     281657.0
# MT-CO1     263384.0
# MALAT1     260312.0
# MT-ATP6    257328.0
# MT-ND4     255600.0
# MT-CYB     190021.0
# MT-ND1     177439.0
# FTL        127240.0
# MT-ND3     126037.0
# MT-ND2     118230.0
# FTH1       110609.0
# RPL13       88817.0
# EEF1A1      80390.0
# RPLP1       78562.0
# RPS18       74014.0
# TMSB10      73605.0
# RPL10       68900.0
# TPT1        68722.0
# S100A6      66527.0
# RPS8        59619.0
# TMSB4X      58447.0
# RPS12       57048.0
# RPL30       55902.0
# RPL13A      55276.0
# RPL8        55110.0
# RPL41       51062.0
# RPL28       50846.0
# B2M         50601.0
# RPS24       49642.0
# MT-ND5      49244.0
# RPS27A      47335.0
# RPS3A       44545.0
# RPL11       43105.0
# RPS4X       42603.0
# RPLP2       41984.0
# RPL19       40784.0
# ACTB        40048.0
# RPS27       39940.0
# RPS2        39831.0
# GAPDH       38758.0
# RPS20       38632.0
# RPL32       38451.0
# RPS3        37911.0
# RPL15       36940.0
# RPL23A      36899.0
# PTMA        34984.0
# RPS19       34908.0
# RPL3        34647.0
# S100A10     34516.0
# dtype: float64

# %%
#visulaize data point
sns.lmplot('x', 'y', data=mat1, fit_reg = False,
          scatter_kws={"s":150},
          hue="cluster_id")
#titlee
plot.title('kmean plot ver2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-489149b1a725> in <module>
#       2 sns.lmplot('x', 'y', data=mat1, fit_reg = False,
#       3           scatter_kws={"s":150},
# ----> 4           hue="cluster_id")
#       5 #titlee
#       6 plot.title('kmean plot ver2')
#
# ~\Miniconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     577     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     578     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 579     data = data[cols]
#     580
#     581     # Initialize the grid
#
# ~\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Miniconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\Miniconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['x', 'y'] not in index"
